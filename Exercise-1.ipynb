# %%
ice_cream_rating = 10

# %%
sleeping_rating = 8

# %%
first_name = "Kei"

# %%
last_name = "Kinoshita"

# %%
my_name = "Kei Kinoshita"

# %%
happiness_rating = (ice_cream_rating+sleeping_rating)*1/2

# %%
happiness_percentage = (ice_cream_rating+sleeping_rating)*1/2*10

# %%
type(ice_cream_rating)
# Out:
# int

# %%
type(sleeping_rating)
# Out:
# int

# %%
type(happiness_rating)
# Out:
# float

# %% [markdown]
# No

# %%
print("My name is",first_name,"and give eating ice cream a socre of",ice_cream_rating,"out of 10")
# Out:
# My name is Kei and give eating ice cream a socre of 10 out of 10

# %%
print("I am",my_name,"and my sleeping enjoyment rating is",sleeping_rating,"/10")
# Out:
# I am Kei Kinoshita and my sleeping enjoyment rating is 8 /10

# %%
print("Based on the factors above, my hapiness rating is",happiness_rating,"out of 10","or",happiness_percentage,"%")
# Out:
# Based on the factors above, my hapiness rating is 9.0 out of 10 or 90.0 %
